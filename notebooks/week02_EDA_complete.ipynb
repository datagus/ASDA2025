# %% [markdown]
# # Exploratory Data Analysis with Python
# <div style="
#     border: 5px solid purple;
#     border-radius: 8px;
#     padding: 0px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# </div>

# %%
import pandas as pd

# %% [markdown]
# <div style="
#     border: 3px solid purple;
#     border-radius: 8px;
#     padding: 12px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
#      Your job is to makes sense of any dataset given and give a preliminary report.
#     <ul>
#       <li>What is the structure of the data?</li>
#       <li>How clean is the dataset?</li>
#       <li>Does it look real or was machine generated?</li>
#       <li>Is it worth it to further analyse it?</li>
#       <li>Are there some  interesting insights that can be pulled already?</li>
#     </ul>
# </div>

# %% [markdown]
# ## The basics - Understanding a dataframe
# <div style="
#     border: 4px solid orange;
#     border-radius: 8px;
#     padding: 0px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# </div>

# %% [markdown]
# <div style="
#     border: 3px solid orange;
#     border-radius: 8px;
#     padding: 12px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# A dataframe is a "size-mutable, potentially heterogeneous tabular data. Data structure also contains labeled axes (rows and columns). Arithmetic operations align on both row and column labels. Can be thought of as a dict-like container for Series objects. The primary pandas data structure."
# Source: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html
# </div>

# %% [markdown]
# ### Building a dataframe from a dictionary
# <div style="
#     border: 2px solid orange;
#     border-radius: 8px;
#     padding: 0px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# </div>

# %%
mydict = {
    "names": ["Gustavo", "Henrik", "Wanja", "Carlo", "Jannik"],
    "scores": [39, 34, 40, 49, 10],
    "fav_food": ["tacos", "pasta", "cake", "döner", "ice cream"]
}

# %%
#pandas library
df = pd.DataFrame(mydict)

# %% [markdown]
# ### Importing data
# <div style="
#     border: 2px solid orange;
#     border-radius: 8px;
#     padding: 0px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# </div>

# %%
#from a csv file
df = pd.read_csv("datasets/socialmedia_engagement.csv")

# %%
#from an excel file --- need to install openpyxl dependency
df = pd.read_excel("datasets/happiness_2015-2019.xlsx")

# %%
#from github
username = "datagus"
repository = "statstutorial2025"
directory = "week5/airbnb_europe.csv"
github_url = f"https://raw.githubusercontent.com/{username}/{repository}/main/{directory}"
df = pd.read_csv(github_url)

# %%
#from a google spreadsheet
gsheet_id = "1wEGvOk504_wnFlv1D9Dw8IFIAaDMtwau"
url = f"https://docs.google.com/spreadsheets/d/{gsheet_id}/export?format=xlsx"
excel = pd.ExcelFile(url)
df = excel.parse("master table")

# %% [markdown]
# ### Inspecting the structure of a dataframe
# <div style="
#     border: 2px solid orange;
#     border-radius: 8px;
#     padding: 0px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# </div>

# %%
#how many columns and rows
df.shape
# Out:
# (892, 47)

# %%
#retriving them separately
rows_num = df.shape[0]
cols_num = df.shape[1]

print(f"This dataset contains {rows_num} rows and {cols_num} columns")
# Out:
# This dataset contains 892 rows and 47 columns

# %%
#another way to getting the number of rows, using len()
len(df)
# Out:
# 892

# %%
#a more detailed overview, an information overview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 47 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Downloaded (1/0)                                                              764 non-null    object
#  1   Authors                                                                       892 non-null    object
#  2   Author full names                                                             880 non-null    object
#  3   Author(s) ID                                                                  879 non-null    object
#  4   Title                                                                         891 non-null    object
#  5   Year                                                                          892 non-null    int64
#  6   Source title                                                                  892 non-null    object
#  7   Volume                                                                        860 non-null    float64
#  8   Issue                                                                         522 non-null    object
#  9   Art. No.                                                                      527 non-null    object
#  10  Page start                                                                    366 non-null    object
#  11  Page end                                                                      366 non-null    object
#  12  Page count                                                                    365 non-null    float64
#  13  Cited by                                                                      892 non-null    int64
#  14  DOI                                                                           886 non-null    object
#  15  Link                                                                          804 non-null    object
#  16  Author Keywords                                                               635 non-null    object
#  17  Index Keywords                                                                582 non-null    object
#  18  Abstract                                                                      861 non-null    object
#  19  Document Type                                                                 881 non-null    object
#  20  Publication Stage                                                             881 non-null    object
#  21  Open Access                                                                   560 non-null    object
#  22  Source                                                                        881 non-null    object
#  23  EID                                                                           892 non-null    object
#  24  SDG                                                                           892 non-null    int64
#  25  AI (yes/no)                                                                   891 non-null    object
#  26  Sustainability (yes/no)                                                       891 non-null    object
#  27  Type of AI
# inductive, text snippet                                           851 non-null    object
#  28  Algorithm(s) used
# inductive, text snippet                                     509 non-null    object
#  29  Method (1) vs. study object (2)                                               845 non-null    object
#  30  AI as buzzword? (0/1)                                                         811 non-null    object
#  31  Core topic (only one)
# short text snippet, inductive                           855 non-null    object
#  32  Role of AI
# deductive                                                          576 non-null    object
#  33  Means (1) vs. end (2)                                                         846 non-null    object
#  34  sustainability definition                                                     489 non-null    object
#  35  Sus_lvl                                                                       841 non-null    object
#  36  empirical/conceptual/review                                                   856 non-null    object
#  37  spatial scale (individual, local, regional, national, supranational, global)  562 non-null    object
#  38  snapshot in time vs. longitudinal study                                       627 non-null    object
#  39  temporal scale (past, present, future)                                        624 non-null    object
#  40  qualitative/quantitative/mixed methods                                        631 non-null    object
#  41  location of the study (country)                                               510 non-null    object
#  42  Dataset used (inductive)                                                      566 non-null    object
#  43  country of the institution of the first author                                855 non-null    object
#  44  Is there an own subsection for policy recommendations? 1/0                    850 non-null    float64
#  45  Notes                                                                         97 non-null     object
#  46  Coding complete                                                               41 non-null     float64
# dtypes: float64(4), int64(3), object(40)
# memory usage: 327.7+ KB

# %%
#checking the first 5 rows
pd.set_option('display.max_columns', None) # to show all columns
#pd.reset_option('display.max_columns')
df.head(5)
# Out:
#   Downloaded (1/0)                                            Authors  \
# 0                1                    Thiebes S.; Lins S.; Sunyaev A.
# 1                1                      Ho J.-H.; Lee G.-G.; Lu M.-T.
# 2                1                                        Bartmann M.
# 3                1                                        Halsband A.
# 4                1  Raman R.; Kumar Nair V.; Nedungadi P.; Ray I.;...
#
#                                    Author full names  \
# 0  Thiebes, Scott (56319399400); Lins, Sebastian ...
# 1  Ho, Juin-Hao (57218510909); Lee, Gwo-Guang (74...
# 2                     Bartmann, Marius (56512092600)
# 3                    Halsband, Aurélie (57562370000)
# 4  Raman, Raghu (36618183700); Kumar Nair, Vinith...
#
#                                         Author(s) ID  \
# 0              56319399400; 56318996100; 24779131200
# 1               57218510909; 7404852393; 55801461400
# 2                                        56512092600
# 3                                        57562370000
# 4  36618183700; 57647914700; 36069838600; 5883060...
#
#                                                Title  Year  \
# 0                Trustworthy artificial intelligence  2021
# 1  Exploring the implementation of a legal AI bot...  2020
# 2  The Ethics of AI-Powered Climate Nudging—How M...  2022
# 3       Sustainable AI and Intergenerational Justice  2022
# 4  Darkweb research: Past, present, and future tr...  2023
#
#                    Source title  Volume Issue Art. No. Page start Page end  \
# 0            Electronic Markets    31.0     2      NaN        447      464
# 1  Sustainability (Switzerland)    12.0    15     5991        NaN      NaN
# 2  Sustainability (Switzerland)    14.0     9     5153        NaN      NaN
# 3  Sustainability (Switzerland)    14.0     7     3922        NaN      NaN
# 4                       Heliyon     9.0    11   e22269        NaN      NaN
#
#    Page count  Cited by                            DOI  \
# 0        17.0       167     10.1007/s12525-020-00441-4
# 1         NaN         8             10.3390/su12155991
# 2         NaN         6             10.3390/su14095153
# 3         NaN         6             10.3390/su14073922
# 4         NaN         1  10.1016/j.heliyon.2023.e22269
#
#                                                 Link  \
# 0  https://www.scopus.com/inward/record.uri?eid=2...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
# 2  https://www.scopus.com/inward/record.uri?eid=2...
# 3  https://www.scopus.com/inward/record.uri?eid=2...
# 4  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                      Author Keywords  \
# 0  artificial intelligence; deep learning; emotio...
# 1  business; digital; education; entrepreneur; In...
# 2  Environmental effects; Green transition; Miner...
# 3  SDGs; ecological sustainability; intergenerati...
# 4  Artificial Intelligence; Climate Change; Energ...
#
#                                       Index Keywords  \
# 0                                                NaN
# 1                                                NaN
# 2  Asia; Economic and social effects; Economics; ...
# 3                                                NaN
# 4  India; artificial intelligence; climate change...
#
#                                             Abstract Document Type  \
# 0  Artificial intelligence (AI) brings forth many...       Article
# 1  This study explores the implementation of lega...       Article
# 2  The number of areas in which artificial intell...       Article
# 3  Recently, attention has been drawn to the sust...       Article
# 4  The Darkweb, part of the deep web, can be acce...       Article
#
#   Publication Stage Open Access  Source                 EID  SDG AI (yes/no)  \
# 0             Final         NaN  Scopus  2-s2.0-85148853990   16           1
# 1             Final         NaN  Scopus  2-s2.0-85168710066   16           1
# 2             Final         NaN  Scopus  2-s2.0-85174445734   16           1
# 3             Final         NaN  Scopus  2-s2.0-85139602753   16           1
# 4             Final         NaN  Scopus  2-s2.0-85185331385   16           1
#
#   Sustainability (yes/no) Type of AI \ninductive, text snippet  \
# 0                       1                              overall
# 1                       1                              overall
# 2                       1                              overall
# 3                       1                              overall
# 4                       1                                  nlp
#
#   Algorithm(s) used\ninductive, text snippet Method (1) vs. study object (2)  \
# 0                                unspecified                               2
# 1                                unspecified                               2
# 2                                unspecified                               2
# 3                                unspecified                               2
# 4                                unspecified                               2
#
#   AI as buzzword? (0/1) Core topic (only one)\nshort text snippet, inductive  \
# 0                     0                              Societal impact of AI
# 1                     0                                       legal AI bot
# 2                     0                 ethics of AI-based climate nudging
# 3                     0                          intergenerational justice
# 4                     0                                           dark web
#
#   Role of AI\ndeductive  Means (1) vs. end (2)  sustainability definition  \
# 0                    NaN                     2                        NaN
# 1                    NaN                     1                        NaN
# 2                    NaN                     1                        NaN
# 3                    NaN                     1  intergenerational justice
# 4                    NaN                     1                     SDG 16
#
#                  Sus_lvl empirical/conceptual/review  \
# 0    weak sustainability                  conceptual
# 1    weak sustainability                   empirical
# 2    weak sustainability                  conceptual
# 3  strong sustainability                  conceptual
# 4  strong sustainability                      review
#
#   spatial scale (individual, local, regional, national, supranational, global)  \
# 0                                                NaN
# 1                                           national
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   snapshot in time vs. longitudinal study  \
# 0                                     NaN
# 1                                 snaphot
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   temporal scale (past, present, future)  \
# 0                                    NaN
# 1                                present
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   qualitative/quantitative/mixed methods location of the study (country)  \
# 0                                    NaN                             NaN
# 1                           quantitative                          Taiwan
# 2                                    NaN                             NaN
# 3                                    NaN                             NaN
# 4                          mixed methods                             NaN
#
#   Dataset used (inductive) country of the institution of the first author  \
# 0                      NaN                                        Germany
# 1                   survey                                         Taiwan
# 2                      NaN                                        Germany
# 3                      NaN                                        Germany
# 4                      NaN                                          India
#
#    Is there an own subsection for policy recommendations? 1/0 Notes  \
# 0                                                0.0            NaN
# 1                                                0.0            NaN
# 2                                                0.0            NaN
# 3                                                0.0            NaN
# 4                                                1.0            NaN
#
#    Coding complete
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
#checking the last 5 rows
df.tail(5)
# Out:
#     Downloaded (1/0)                                            Authors  \
# 887                1                           Zhang Y.; Ji Y.; Qian H.
# 888                1                                   Jang J.; Kyun S.
# 889                1  Kabukye J.K.; Namugga J.; Mpamani C.J.; Katumb...
# 890                1                           Deng M.; Liu Y.; Chen L.
# 891                1  Zhu X.; Yao Q.; Dai W.; Ji L.; Yao Y.; Pang B....
#
#                                      Author full names  \
# 887  Zhang, Yang (57471054500); Ji, Yuanhui (572047...
# 888                          Jang, Jiyoung; Kyun, Suna
# 889  Kabukye, Johnblack K.; Namugga, Jane; Mpamani,...
# 890             Deng, Meizhen; Liu, Yimeng; Chen, Ling
# 891  Zhu, Xingce; Yao, Qiang; Dai, Wei; Ji, Lu; Yao...
#
#                                           Author(s) ID  \
# 887              57471054500; 57204776640; 55186013100
# 888                                                NaN
# 889  57205140187; 57201368167; 57403715300; 3623907...
# 890              58606568400; 58605588800; 57700546300
# 891  58221931100; 55588525000; 56366749800; 5684438...
#
#                                                  Title  Year  \
# 887  Progress in thermodynamic simulation and syste...  2021
# 888  An Innovative Career Management Platform Empow...  2022
# 889  Implementing Smartphone-Based Telemedicine for...  2023
# 890  AI-driven innovation in ethnic clothing design...  2023
# 891  Cervical cancer screening aided by artificial ...  2023
#
#                                           Source title  Volume Issue Art. No.  \
# 887                         Green Chemical Engineering     2.0     3      NaN
# 888  Journal of Logistics, Informatics and Service ...     9.0     1      NaN
# 889               Journal of Medical Internet Research    25.0     1   e45132
# 890                        Electronic Research Archive    31.0     9      NaN
# 891          Bulletin of the World Health Organization   101.0     6      NaN
#
#     Page start Page end  Page count  Cited by                        DOI  \
# 887        266      283        17.0        26  10.1016/j.gce.2021.06.003
# 888        274      290        16.0         7    10.33168/LISS.2022.0117
# 889        NaN      NaN         NaN         0              10.2196/45132
# 890       5793     5814        21.0         0        10.3934/era.2023295
# 891        381      390         9.0         0      10.2471/BLT.22.289061
#
#                                                   Link  \
# 887  https://www.scopus.com/inward/record.uri?eid=2...
# 888  https://www.scopus.com/inward/record.uri?eid=2...
# 889  https://www.scopus.com/inward/record.uri?eid=2...
# 890  https://www.scopus.com/inward/record.uri?eid=2...
# 891  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                        Author Keywords  \
# 887                                                nil
# 888  artificial intelligence; big data; blockchain;...
# 889  cervical cancer; cervicography; digital health...
# 890  Artificial Intelligence; cultural preservation...
# 891                                                NaN
#
#                                         Index Keywords  \
# 887                                                nil
# 888                                               n.a.
# 889  Artificial Intelligence; Early Detection of Ca...
# 890                                               n.a.
# 891                                                NaN
#
#                                               Abstract Document Type  \
# 887  Due to the shortage of fossil energy, biomass ...        Review
# 888  With the advent of the fourth industrial revol...       Article
# 889  Background: In Uganda, cervical cancer (CaCx) ...       Article
# 890  This study delves into the innovative applicat...       Article
# 891  Objective To implement and evaluate a large-sc...       Article
#
#     Publication Stage                                        Open Access  \
# 887             Final                  All Open Access; Gold Open Access
# 888             Final                                                NaN
# 889             Final  All Open Access; Gold Open Access; Green Open ...
# 890             Final  All Open Access; Gold Open Access; Green Open ...
# 891             Final  All Open Access; Bronze Open Access; Green Ope...
#
#      Source                 EID  SDG AI (yes/no) Sustainability (yes/no)  \
# 887  Scopus  2-s2.0-85126637055    9           1                       1
# 888  Scopus  2-s2.0-85128453304    5           1                       1
# 889  Scopus  2-s2.0-85174748358    5           1                       1
# 890  Scopus  2-s2.0-85171645006    5           1                       1
# 891  Scopus  2-s2.0-85160969682    5           1                       1
#
#                   Type of AI \ninductive, text snippet  \
# 887                                                 AI
# 888  artificial intelligence; big data;\nblockchain...
# 889                            AI; supervised learning
# 890  AI; unsupervised learning; ML;  Natural Langua...
# 891                                                 Ai
#
#             Algorithm(s) used\ninductive, text snippet  \
# 887                                                NaN
# 888                                               n.a.
# 889                                               n.a.
# 890  Multimodal Unsupervised Image-to-Image Transla...
# 891                                               n.a.
#
#     Method (1) vs. study object (2) AI as buzzword? (0/1)  \
# 887                               2                     1
# 888                               2                     0
# 889                               1                     0
# 890                               2                     0
# 891                               1                     0
#
#     Core topic (only one)\nshort text snippet, inductive  \
# 887       Sustainable utilization of biomass resources
# 888  customized career management platform for fema...
# 889  smartphone-based store-and-forward telemedicin...
# 890  application of Artificial Intelligence (AI) an...
# 891  online cervical cancer screening programme usi...
#
#     Role of AI\ndeductive  Means (1) vs. end (2)  \
# 887                    NaN                     1
# 888                    NaN                     1
# 889            Forecasting                     1
# 890                    NaN                     1
# 891            Forecasting                     1
#
#                              sustainability definition Sus_lvl  \
# 887                                                NaN    weak
# 888  buzzword; "sustainable career management of ta...    weak
# 889                                buzzword; longevity    weak
# 890  buzzword; "sustainable development of ethnic f...    weak
# 891                                           buzzword    weak
#
#     empirical/conceptual/review  \
# 887                      Review
# 888                  conceptual
# 889                   empirical
# 890                   empirical
# 891                   empirical
#
#     spatial scale (individual, local, regional, national, supranational, global)  \
# 887                                                NaN
# 888                                               n.a.
# 889                                           regional
# 890                                              local
# 891                                           regional
#
#     snapshot in time vs. longitudinal study  \
# 887                                     NaN
# 888                                    n.a.
# 889                        snapshot in time
# 890                        snapshot in time
# 891                        snapshot in time
#
#     temporal scale (past, present, future)  \
# 887                                    NaN
# 888                                   n.a.
# 889                                present
# 890                                present
# 891                                present
#
#     qualitative/quantitative/mixed methods location of the study (country)  \
# 887                                    NaN                             NaN
# 888                                   n.a.                            n.a.
# 889                            qualitative                          Uganda
# 890                          mixed methods                          Biasha
# 891                           quantitative            Hubei Province China
#
#     Dataset used (inductive) country of the institution of the first author  \
# 887                      NaN                                          China
# 888                     n.a.                                    South Korea
# 889                     n.a.                                 Sweden; Uganda
# 890                     n.a.                                          China
# 891                      NaN                                          China
#
#      Is there an own subsection for policy recommendations? 1/0 Notes  \
# 887                                                0.0            NaN
# 888                                                0.0            NaN
# 889                                                0.0            NaN
# 890                                                0.0            NaN
# 891                                                0.0            NaN
#
#      Coding complete
# 887              NaN
# 888              NaN
# 889              NaN
# 890              NaN
# 891              NaN

# %%
#checking a random slice of the dataframe
df.sample(9)
# Out:
#     Downloaded (1/0)                                            Authors  \
# 701              NaN           Fan D.; Su X.; Weng B.; Wang T.; Yang F.
# 655                1  Donisi L.; Cesarelli G.; Pisani N.; Ponsiglion...
# 823                1                                 MANN S.; HUBERT M.
# 505                1  Nti E.K.; Cobbina S.J.; Attafuah E.E.; Opoku E...
# 45                 1                         Kucuker D.M.; Baskent E.Z.
# 564                1  Thangavel K.; Spiller D.; Sabatini R.; Marzocc...
# 497                1                Do T.-T.-H.; Schnitzer H.; Le T.-H.
# 92                 1                              Allam Z.; Dhunny Z.A.
# 107                1                       Zahmatkesh H.; Al-Turjman F.
#
#                                      Author full names  \
# 701  Fan, Dongliang (57190302955); Su, Xiaoyun (572...
# 655  Donisi, Leandro (57212085515); Cesarelli, Gius...
# 823  MANN, SUPREET (57208395499); HUBERT, MARTIN (2...
# 505  Nti, Emmanuel Kwame (24338860400); Cobbina, Sa...
# 45   Kucuker, Derya Mumcu (37112952500); Baskent, E...
# 564  Thangavel, Kathiravan (57222007577); Spiller, ...
# 497  Do, Thi-Thu-Huyen (56166847900); Schnitzer, Ha...
# 92   Allam, Zaheer (57205544315); Dhunny, Zaynah A....
# 107  Zahmatkesh, Hadi (56541718800); Al-Turjman, Fa...
#
#                                           Author(s) ID  \
# 701  57190302955; 57204881851; 57751948400; 5775091...
# 655  57212085515; 57212086815; 58033391800; 5634897...
# 823                           57208395499; 26026927500
# 505  24338860400; 26654761400; 57501195900; 5749367...
# 45                             37112952500; 6701704098
# 564  57222007577; 57225928954; 56962744800; 3560734...
# 497               56166847900; 7006833141; 57191503667
# 92                            57205544315; 57205545550
# 107                           56541718800; 20336944100
#
#                                                  Title  Year  \
# 701  Research Progress on Remote Sensing Classifica...  2021
# 655  Wearable Sensors and Artificial Intelligence f...  2022
# 823      AI4D: Artificial Intelligence for Development  2020
# 505  Environmental sustainability technologies in b...  2022
# 45   Impact of forest management intensity on mushr...  2017
# 564  Near Real-Time Wildfire Management Using Distr...  2023
# 497  A decision support framework considering susta...  2014
# 92   On big data, artificial intelligence and smart...  2019
# 107  Fog computing for sustainable smart cities in ...  2020
#
#                                    Source title  Volume Issue Art. No.  \
# 701                             AgriEngineering     3.0     4      NaN
# 655                                 Diagnostics    12.0    12     3048
# 823      International Journal of Communication    14.0   NaN      NaN
# 505                         Sustainable Futures     4.0   NaN   100068
# 45                Forest Ecology and Management   389.0   NaN      NaN
# 564  IEEE Geoscience and Remote Sensing Letters    20.0   NaN  5500705
# 497               Journal of Cleaner Production    78.0   NaN      NaN
# 92                                       Cities    89.0   NaN      NaN
# 107              Sustainable Cities and Society    59.0   NaN   102139
#
#     Page start Page end  Page count  Cited by                             DOI  \
# 701        971      989        18.0         5  10.3390/agriengineering3040061
# 655        NaN      NaN         NaN         8     10.3390/diagnostics12123048
# 823       4385     4405        20.0         3                             NaN
# 505        NaN      NaN         NaN        18      10.1016/j.sftr.2022.100068
# 45         240      248         8.0        11    10.1016/j.foreco.2016.12.035
# 564        NaN      NaN         NaN        13       10.1109/LGRS.2022.3229173
# 497        112      120         8.0        22   10.1016/j.jclepro.2014.04.044
# 92          80       91        11.0       555    10.1016/j.cities.2019.01.032
# 107        NaN      NaN         NaN       118       10.1016/j.scs.2020.102139
#
#                                                   Link  \
# 701  https://www.scopus.com/inward/record.uri?eid=2...
# 655  https://www.scopus.com/inward/record.uri?eid=2...
# 823  https://www.scopus.com/inward/record.uri?eid=2...
# 505  https://www.scopus.com/inward/record.uri?eid=2...
# 45   https://www.scopus.com/inward/record.uri?eid=2...
# 564  https://www.scopus.com/inward/record.uri?eid=2...
# 497  https://www.scopus.com/inward/record.uri?eid=2...
# 92   https://www.scopus.com/inward/record.uri?eid=2...
# 107  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                        Author Keywords  \
# 701                                                nil
# 655                                                NaN
# 823                                                nil
# 505                                                  -
# 45                                                 NaN
# 564  Climate action (SDG-13) is an integral part of...
# 497                                                  -
# 92   Cities are increasingly turning towards specia...
# 107  In recent decade, the number of devices involv...
#
#                                         Index Keywords  \
# 701                                                nil
# 655                                                NaN
# 823                                                nil
# 505                                                  -
# 45                                                 NaN
# 564  1-D convolutional neural network (CNN); climat...
# 497                                                  -
# 92   Artificial intelligence; Big data; Internet of...
# 107  Caching; Fog computing; IoT; Machine learning;...
#
#                                               Abstract Document Type  \
# 701  Crop planting area and spatial distribution in...        Review
# 655  Physical ergonomics has established itself as ...        Review
# 823  We derive a conceptual bridge between technica...       Article
# 505  Artificial Intelligence (AI) has become an imp...        Review
# 45   Well-researched and sound integration of non-w...       Article
# 564  Australia; Climate change; Data handling; Defo...       Article
# 497  A specific combination of rule-based technique...       Article
# 92   artificial intelligence; conceptual framework;...       Article
# 107  Antennas; Artificial intelligence; Energy effi...       Article
#
#     Publication Stage                                        Open Access  \
# 701             Final                  All Open Access; Gold Open Access
# 655             Final  All Open Access; Gold Open Access; Green Open ...
# 823             Final                                                NaN
# 505             Final                  All Open Access; Gold Open Access
# 45              Final                                                NaN
# 564             Final           All Open Access; Hybrid Gold Open Access
# 497             Final                                                NaN
# 92              Final                                                NaN
# 107             Final                                                NaN
#
#      Source                 EID  SDG AI (yes/no) Sustainability (yes/no)  \
# 701  Scopus  2-s2.0-85132262086    2           1                       1
# 655  Scopus  2-s2.0-85144871876    3           1                       1
# 823  Scopus  2-s2.0-85099547866   18           1                       1
# 505  Scopus  2-s2.0-85126586294    7           1                       1
# 45   Scopus  2-s2.0-85008975730   15           1                       1
# 564  Scopus  2-s2.0-85144780070   13         Yes                     Yes
# 497  Scopus  2-s2.0-84904259753    7           1                       1
# 92   Scopus  2-s2.0-85060456132   11           1                       1
# 107  Scopus  2-s2.0-85084182624   11           1                       1
#
#                   Type of AI \ninductive, text snippet  \
# 701                                   Machine Learning
# 655  artificial intelligence; machine learning; dee...
# 823                                  AI, deep learning
# 505                                            overall
# 45                                 supervised learning
# 564                            artificial intelligence
# 497                                      Decision Tree
# 92                                 AI;machine learning
# 107                                             AI; ML
#
#             Algorithm(s) used\ninductive, text snippet  \
# 701                                     Neural Network
# 655  ensemble classifiers; Support Vector Machines;...
# 823                                                NaN
# 505                                        unspecified
# 45                             decision support system
# 564                Convolutional Neural Networks (CNN)
# 497                   fuzzy analytic hierarchy process
# 92            artifical neural networks;fuzzy networks
# 107                                               N.A.
#
#     Method (1) vs. study object (2) AI as buzzword? (0/1)  \
# 701                               1                     0
# 655                               2                     0
# 823                               2                     0
# 505                               1                     0
# 45                                1                     0
# 564                               2                     0
# 497                               1                     0
# 92                                2                     0
# 107                               2                     1
#
#     Core topic (only one)\nshort text snippet, inductive  \
# 701                                   Farm management
# 655                                physical ergonomics
# 823           Role of AI for International Development
# 505                AI used in sustainable technologies
# 45   Impact of forest management intensity on mushr...
# 564  space based detection of fire by using AI with...
# 497  decision support to select food processes like...
# 92            smart city; big data, IoT and blockchain
# 107           smart city; big data, IoT and blockchain
#
#               Role of AI\ndeductive  Means (1) vs. end (2)  \
# 701   Data mining and Remote sensing                     2
# 655                              NaN                     1
# 823                              NaN                     1
# 505                              all                     1
# 45       Fast approximate simulation                     1
# 564  Data mining and remote sensing                      2
# 497              System optimization                     1
# 92               System optimization                     1
# 107                              NaN                     1
#
#                              sustainability definition              Sus_lvl  \
# 701                                                NaN                 Weak
# 655                                                NaN  weak sustainability
# 823                                                NaN                 weak
# 505                AI for environmental sustainability               strong
# 45                                              values               medium
# 564                                               SDGs               medium
# 497                                                NaN                 weak
# 92   potentiality of building more sustainable, saf...               strong
# 107  Sustainability is referred to the use of renew...               strong
#
#     empirical/conceptual/review  \
# 701                   Empirical
# 655                      review
# 823                  Conceptual
# 505                      review
# 45                    empirical
# 564                   empirical
# 497                   empirical
# 92                       review
# 107                  conceptual
#
#     spatial scale (individual, local, regional, national, supranational, global)  \
# 701                                             Global
# 655                                                NaN
# 823                                                NaN
# 505                                               n.a.
# 45                                               local
# 564                                                NaN
# 497                                              local
# 92                                                N.A.
# 107                                               N.A.
#
#     snapshot in time vs. longitudinal study  \
# 701                            Longitudinal
# 655                                     NaN
# 823                                     NaN
# 505                                    n.a.
# 45                       longitudinal study
# 564                        snapshot in time
# 497                        snapshot in time
# 92                                     N.A.
# 107                                    N.A.
#
#     temporal scale (past, present, future)  \
# 701                                Present
# 655                                    NaN
# 823                                    NaN
# 505                                   n.a.
# 45                                  future
# 564                                present
# 497                                present
# 92                                    N.A.
# 107                                   N.A.
#
#     qualitative/quantitative/mixed methods location of the study (country)  \
# 701                                    NaN                           China
# 655                            qualitative                             NaN
# 823                                    NaN                             NaN
# 505                                   n.a.                            n.a.
# 45                            quantitative                          Turkey
# 564                           quantitative                             NaN
# 497                           quantitative                         Austria
# 92                                    N.A.                            N.A.
# 107                                   N.A.                            N.A.
#
#                               Dataset used (inductive)  \
# 701                                           Internet
# 655                                                NaN
# 823                                                NaN
# 505                                               n.a.
# 45   field inventory, forest stand parameters, mark...
# 564                                        PRISMA data
# 497  database of food products and their thermal pr...
# 92                                                N.A.
# 107                                               N.A.
#
#     country of the institution of the first author  \
# 701                                          China
# 655                                          Italy
# 823                                            USA
# 505                                          Ghana
# 45                                          Turkey
# 564                                      Australia
# 497                                        Austria
# 92                                       Australia
# 107                                         Norway
#
#      Is there an own subsection for policy recommendations? 1/0  \
# 701                                                0.0
# 655                                                0.0
# 823                                                0.0
# 505                                                0.0
# 45                                                 0.0
# 564                                                0.0
# 497                                                0.0
# 92                                                 0.0
# 107                                                0.0
#
#                Notes  Coding complete
# 701              NaN              NaN
# 655              NaN              NaN
# 823              NaN              NaN
# 505              NaN              NaN
# 45               NaN              1.0
# 564              NaN              NaN
# 497              NaN              NaN
# 92               NaN              NaN
# 107  deleted in SDG7              NaN

# %%
#checking the columns names
df.columns
# Out:
# Index(['Downloaded (1/0)', 'Authors', 'Author full names', 'Author(s) ID',
#        'Title', 'Year', 'Source title', 'Volume', 'Issue', 'Art. No.',
#        'Page start', 'Page end', 'Page count', 'Cited by', 'DOI', 'Link',
#        'Author Keywords', 'Index Keywords', 'Abstract', 'Document Type',
#        'Publication Stage', 'Open Access', 'Source', 'EID', 'SDG',
#        'AI (yes/no)', 'Sustainability (yes/no)',
#        'Type of AI \ninductive, text snippet',
#        'Algorithm(s) used\ninductive, text snippet',
#        'Method (1) vs. study object (2)', 'AI as buzzword? (0/1)',
#        'Core topic (only one)\nshort text snippet, inductive',
#        'Role of AI\ndeductive ', 'Means (1) vs. end (2)',
#        'sustainability definition', 'Sus_lvl', 'empirical/conceptual/review',
#        'spatial scale (individual, local, regional, national, supranational, global)',
#        'snapshot in time vs. longitudinal study',
#        'temporal scale (past, present, future)',
#        'qualitative/quantitative/mixed methods',
#        'location of the study (country)', 'Dataset used (inductive)',
#        'country of the institution of the first author',
#        'Is there an own subsection for policy recommendations? 1/0', 'Notes',
#        'Coding complete'],
#       dtype='object')

# %%
##getting the index
df.index
# Out:
# RangeIndex(start=0, stop=892, step=1)

# %%
#getting some descriptive statistics for numeric
df.describe()
# Out:
#               Year       Volume  Page count    Cited by         SDG  \
# count   892.000000   860.000000  365.000000  892.000000  892.000000
# mean   2020.880045    92.473256   15.583562   40.318386    8.165919
# std       2.754888   229.278177    8.631132   73.286039    4.722542
# min    1998.000000     1.000000    3.000000    0.000000    1.000000
# 25%    2020.000000    12.000000   10.000000    6.000000    4.000000
# 50%    2022.000000    21.000000   14.000000   19.000000    7.000000
# 75%    2023.000000    72.000000   19.000000   41.000000   12.000000
# max    2024.000000  2023.000000   68.000000  798.000000   18.000000
#
#        Is there an own subsection for policy recommendations? 1/0  \
# count                                         850.000000
# mean                                            0.145882
# std                                             0.353196
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Coding complete
# count             41.0
# mean               1.0
# std                0.0
# min                1.0
# 25%                1.0
# 50%                1.0
# 75%                1.0
# max                1.0

# %%
#getting some descriptive statistics for categories or object data types
df.describe(include="object")
# Out:
#         Downloaded (1/0)     Authors             Author full names  \
# count                764         892                           880
# unique                 3         868                           857
# top                    1  Mhlanga D.  Mhlanga, David (57218104204)
# freq                 758           4                             4
#
#         Author(s) ID                                              Title  \
# count            879                                                891
# unique           853                                                875
# top      57218104204  A review of the Artificial Intelligence (AI) b...
# freq               4                                                  2
#
#                         Source title  Issue  Art. No.  Page start  Page end  \
# count                            892    522       527         366       366
# unique                           444     67       509         306       327
# top     Sustainability (Switzerland)      1        14           1       171
# freq                             105     74         4          17         4
#
#                                  DOI  \
# count                            886
# unique                           870
# top     10.1016/j.compag.2023.107836
# freq                               2
#
#                                                      Link Author Keywords  \
# count                                                 804             635
# unique                                                789             353
# top     https://www.scopus.com/inward/record.uri?eid=2...             nil
# freq                                                    2             200
#
#        Index Keywords                 Abstract Document Type  \
# count             582                      861           881
# unique            298                      846             2
# top               nil  [No abstract available]       Article
# freq              200                        4           677
#
#        Publication Stage                        Open Access  Source  \
# count                881                                560     881
# unique                 2                                  8       1
# top                Final  All Open Access; Gold Open Access  Scopus
# freq                 857                                204     881
#
#                        EID  AI (yes/no)  Sustainability (yes/no)  \
# count                  892          891                      891
# unique                 873            5                        7
# top     2-s2.0-85148853990            1                        1
# freq                     2          722                      713
#
#        Type of AI \ninductive, text snippet  \
# count                                   851
# unique                                  286
# top                                      AI
# freq                                    281
#
#        Algorithm(s) used\ninductive, text snippet  \
# count                                         509
# unique                                        361
# top                                          n.a.
# freq                                           36
#
#         Method (1) vs. study object (2)  AI as buzzword? (0/1)  \
# count                               845                    811
# unique                                6                      3
# top                                   2                      0
# freq                                538                    707
#
#        Core topic (only one)\nshort text snippet, inductive  \
# count                                                 855
# unique                                                735
# top                                         Smart farming
# freq                                                   17
#
#        Role of AI\ndeductive   Means (1) vs. end (2)  \
# count                     576                    846
# unique                     48                      7
# top       System optimization                      1
# freq                      150                    663
#
#        sustainability definition Sus_lvl empirical/conceptual/review  \
# count                        489     841                         856
# unique                       223      12                          18
# top                         SDGs    weak                   empirical
# freq                          75     455                         332
#
#        spatial scale (individual, local, regional, national, supranational, global)  \
# count                                                 562
# unique                                                 26
# top                                                 local
# freq                                                  131
#
#        snapshot in time vs. longitudinal study  \
# count                                      627
# unique                                      16
# top                                   snapshot
# freq                                       307
#
#        temporal scale (past, present, future)  \
# count                                     624
# unique                                     22
# top                                   present
# freq                                      365
#
#        qualitative/quantitative/mixed methods location of the study (country)  \
# count                                     631                             510
# unique                                     20                             119
# top                              quantitative                            n.a.
# freq                                      328                              86
#
#        Dataset used (inductive)  \
# count                       566
# unique                      312
# top                        n.a.
# freq                         82
#
#        country of the institution of the first author  \
# count                                             855
# unique                                            107
# top                                             China
# freq                                               94
#
#                              Notes
# count                           97
# unique                          41
# top     Duplicate, deleted in SDG9
# freq                            15

# %% [markdown]
# ### Quality of the dataframe
# <div style="
#     border: 2px solid orange;
#     border-radius: 8px;
#     padding: 0px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# </div>

# %%
#checking duplicates in the dataframe
df.duplicated().sum()
print(int(df.duplicated().sum()))
# Out:
# 0

# %%
#how many missing values
df.isna().sum()
# Out:
# Downloaded (1/0)                                                                128
# Authors                                                                           0
# Author full names                                                                12
# Author(s) ID                                                                     13
# Title                                                                             1
# Year                                                                              0
# Source title                                                                      0
# Volume                                                                           32
# Issue                                                                           370
# Art. No.                                                                        365
# Page start                                                                      526
# Page end                                                                        526
# Page count                                                                      527
# Cited by                                                                          0
# DOI                                                                               6
# Link                                                                             88
# Author Keywords                                                                 257
# Index Keywords                                                                  310
# Abstract                                                                         31
# Document Type                                                                    11
# Publication Stage                                                                11
# Open Access                                                                     332
# Source                                                                           11
# EID                                                                               0
# SDG                                                                               0
# AI (yes/no)                                                                       1
# Sustainability (yes/no)                                                           1
# Type of AI \ninductive, text snippet                                             41
# Algorithm(s) used\ninductive, text snippet                                      383
# Method (1) vs. study object (2)                                                  47
# AI as buzzword? (0/1)                                                            81
# Core topic (only one)\nshort text snippet, inductive                             37
# Role of AI\ndeductive                                                           316
# Means (1) vs. end (2)                                                            46
# sustainability definition                                                       403
# Sus_lvl                                                                          51
# empirical/conceptual/review                                                      36
# spatial scale (individual, local, regional, national, supranational, global)    330
# snapshot in time vs. longitudinal study                                         265
# temporal scale (past, present, future)                                          268
# qualitative/quantitative/mixed methods                                          261
# location of the study (country)                                                 382
# Dataset used (inductive)                                                        326
# country of the institution of the first author                                   37
# Is there an own subsection for policy recommendations? 1/0                       42
# Notes                                                                           795
# Coding complete                                                                 851
# dtype: int64

# %%
#checking the datatypes
df.dtypes
# Out:
# Downloaded (1/0)                                                                 object
# Authors                                                                          object
# Author full names                                                                object
# Author(s) ID                                                                     object
# Title                                                                            object
# Year                                                                              int64
# Source title                                                                     object
# Volume                                                                          float64
# Issue                                                                            object
# Art. No.                                                                         object
# Page start                                                                       object
# Page end                                                                         object
# Page count                                                                      float64
# Cited by                                                                          int64
# DOI                                                                              object
# Link                                                                             object
# Author Keywords                                                                  object
# Index Keywords                                                                   object
# Abstract                                                                         object
# Document Type                                                                    object
# Publication Stage                                                                object
# Open Access                                                                      object
# Source                                                                           object
# EID                                                                              object
# SDG                                                                               int64
# AI (yes/no)                                                                      object
# Sustainability (yes/no)                                                          object
# Type of AI \ninductive, text snippet                                             object
# Algorithm(s) used\ninductive, text snippet                                       object
# Method (1) vs. study object (2)                                                  object
# AI as buzzword? (0/1)                                                            object
# Core topic (only one)\nshort text snippet, inductive                             object
# Role of AI\ndeductive                                                            object
# Means (1) vs. end (2)                                                            object
# sustainability definition                                                        object
# Sus_lvl                                                                          object
# empirical/conceptual/review                                                      object
# spatial scale (individual, local, regional, national, supranational, global)     object
# snapshot in time vs. longitudinal study                                          object
# temporal scale (past, present, future)                                           object
# qualitative/quantitative/mixed methods                                           object
# location of the study (country)                                                  object
# Dataset used (inductive)                                                         object
# country of the institution of the first author                                   object
# Is there an own subsection for policy recommendations? 1/0                      float64
# Notes                                                                            object
# Coding complete                                                                 float64
# dtype: object

# %%
#how many unique values are in the Post Type column
df["SDG"].unique()
# Out:
# array([16, 14, 13, 15,  8, 10,  5, 11,  6, 12,  4,  7,  1,  3,  2, 18,  9])

# %%
#How many unique values are in the Post Content column
df["SDG"].nunique()
# Out:
# 17

# %%
#getting a contingency table of SDGs
df["SDG"].value_counts()
# Out:
# SDG
# 4     100
# 3      96
# 6      91
# 2      91
# 11     86
# 13     79
# 7      75
# 12     71
# 9      62
# 18     48
# 15     30
# 14     18
# 16     13
# 8      11
# 5       8
# 1       8
# 10      5
# Name: count, dtype: int64

# %%
#saving the table into a variablel
study_locations = df["location of the study (country)"].value_counts()

# %%
#converting the object into a Data Frame
slocations_df = pd.DataFrame(study_locations)
slocations_df
# Out:
#                                                  count
# location of the study (country)
# n.a.                                                86
# N.A.                                                53
# China                                               40
# India                                               28
# Iran                                                23
# ...                                                ...
# Denmark                                              1
# Northern region of Colombia                          1
# state of Zacatecas ​in Mexico                        1
# office building, Beijing, China;ISO New England      1
# Hubei Province China                                 1
#
# [119 rows x 1 columns]

# %%
#reseting the index
slocations_df = slocations_df.reset_index(drop=False)
slocations_df
# Out:
#                      location of the study (country)  count
# 0                                               n.a.     86
# 1                                               N.A.     53
# 2                                              China     40
# 3                                              India     28
# 4                                               Iran     23
# ..                                               ...    ...
# 114                                          Denmark      1
# 115                      Northern region of Colombia      1
# 116                    state of Zacatecas ​in Mexico      1
# 117  office building, Beijing, China;ISO New England      1
# 118                             Hubei Province China      1
#
# [119 rows x 2 columns]

# %% [markdown]
# ## Dataframe Operations
# <div style="
#     border: 4px solid green;
#     border-radius: 8px;
#     padding: 0px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# </div>

# %% [markdown]
# ### Modifying the index
# <div style="
#     border: 2px solid green;
#     border-radius: 8px;
#     padding: 0px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# </div>

# %%
#making a copy of your dataset. Recommended especially if you are modifying the original df
copy_df = df.copy()

# %%
# putting a custom index, for example that 
#for example, starting from 100, you need to make sure, your index fits the lenght of rows
copy_df.index = range(1, len(df)+1)
copy_df.head(5)
# Out:
#   Downloaded (1/0)                                            Authors  \
# 1                1                    Thiebes S.; Lins S.; Sunyaev A.
# 2                1                      Ho J.-H.; Lee G.-G.; Lu M.-T.
# 3                1                                        Bartmann M.
# 4                1                                        Halsband A.
# 5                1  Raman R.; Kumar Nair V.; Nedungadi P.; Ray I.;...
#
#                                    Author full names  \
# 1  Thiebes, Scott (56319399400); Lins, Sebastian ...
# 2  Ho, Juin-Hao (57218510909); Lee, Gwo-Guang (74...
# 3                     Bartmann, Marius (56512092600)
# 4                    Halsband, Aurélie (57562370000)
# 5  Raman, Raghu (36618183700); Kumar Nair, Vinith...
#
#                                         Author(s) ID  \
# 1              56319399400; 56318996100; 24779131200
# 2               57218510909; 7404852393; 55801461400
# 3                                        56512092600
# 4                                        57562370000
# 5  36618183700; 57647914700; 36069838600; 5883060...
#
#                                                Title  Year  \
# 1                Trustworthy artificial intelligence  2021
# 2  Exploring the implementation of a legal AI bot...  2020
# 3  The Ethics of AI-Powered Climate Nudging—How M...  2022
# 4       Sustainable AI and Intergenerational Justice  2022
# 5  Darkweb research: Past, present, and future tr...  2023
#
#                    Source title  Volume Issue Art. No. Page start Page end  \
# 1            Electronic Markets    31.0     2      NaN        447      464
# 2  Sustainability (Switzerland)    12.0    15     5991        NaN      NaN
# 3  Sustainability (Switzerland)    14.0     9     5153        NaN      NaN
# 4  Sustainability (Switzerland)    14.0     7     3922        NaN      NaN
# 5                       Heliyon     9.0    11   e22269        NaN      NaN
#
#    Page count  Cited by                            DOI  \
# 1        17.0       167     10.1007/s12525-020-00441-4
# 2         NaN         8             10.3390/su12155991
# 3         NaN         6             10.3390/su14095153
# 4         NaN         6             10.3390/su14073922
# 5         NaN         1  10.1016/j.heliyon.2023.e22269
#
#                                                 Link  \
# 1  https://www.scopus.com/inward/record.uri?eid=2...
# 2  https://www.scopus.com/inward/record.uri?eid=2...
# 3  https://www.scopus.com/inward/record.uri?eid=2...
# 4  https://www.scopus.com/inward/record.uri?eid=2...
# 5  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                      Author Keywords  \
# 1  artificial intelligence; deep learning; emotio...
# 2  business; digital; education; entrepreneur; In...
# 3  Environmental effects; Green transition; Miner...
# 4  SDGs; ecological sustainability; intergenerati...
# 5  Artificial Intelligence; Climate Change; Energ...
#
#                                       Index Keywords  \
# 1                                                NaN
# 2                                                NaN
# 3  Asia; Economic and social effects; Economics; ...
# 4                                                NaN
# 5  India; artificial intelligence; climate change...
#
#                                             Abstract Document Type  \
# 1  Artificial intelligence (AI) brings forth many...       Article
# 2  This study explores the implementation of lega...       Article
# 3  The number of areas in which artificial intell...       Article
# 4  Recently, attention has been drawn to the sust...       Article
# 5  The Darkweb, part of the deep web, can be acce...       Article
#
#   Publication Stage Open Access  Source                 EID  SDG AI (yes/no)  \
# 1             Final         NaN  Scopus  2-s2.0-85148853990   16           1
# 2             Final         NaN  Scopus  2-s2.0-85168710066   16           1
# 3             Final         NaN  Scopus  2-s2.0-85174445734   16           1
# 4             Final         NaN  Scopus  2-s2.0-85139602753   16           1
# 5             Final         NaN  Scopus  2-s2.0-85185331385   16           1
#
#   Sustainability (yes/no) Type of AI \ninductive, text snippet  \
# 1                       1                              overall
# 2                       1                              overall
# 3                       1                              overall
# 4                       1                              overall
# 5                       1                                  nlp
#
#   Algorithm(s) used\ninductive, text snippet Method (1) vs. study object (2)  \
# 1                                unspecified                               2
# 2                                unspecified                               2
# 3                                unspecified                               2
# 4                                unspecified                               2
# 5                                unspecified                               2
#
#   AI as buzzword? (0/1) Core topic (only one)\nshort text snippet, inductive  \
# 1                     0                              Societal impact of AI
# 2                     0                                       legal AI bot
# 3                     0                 ethics of AI-based climate nudging
# 4                     0                          intergenerational justice
# 5                     0                                           dark web
#
#   Role of AI\ndeductive  Means (1) vs. end (2)  sustainability definition  \
# 1                    NaN                     2                        NaN
# 2                    NaN                     1                        NaN
# 3                    NaN                     1                        NaN
# 4                    NaN                     1  intergenerational justice
# 5                    NaN                     1                     SDG 16
#
#                  Sus_lvl empirical/conceptual/review  \
# 1    weak sustainability                  conceptual
# 2    weak sustainability                   empirical
# 3    weak sustainability                  conceptual
# 4  strong sustainability                  conceptual
# 5  strong sustainability                      review
#
#   spatial scale (individual, local, regional, national, supranational, global)  \
# 1                                                NaN
# 2                                           national
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   snapshot in time vs. longitudinal study  \
# 1                                     NaN
# 2                                 snaphot
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
#
#   temporal scale (past, present, future)  \
# 1                                    NaN
# 2                                present
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
#
#   qualitative/quantitative/mixed methods location of the study (country)  \
# 1                                    NaN                             NaN
# 2                           quantitative                          Taiwan
# 3                                    NaN                             NaN
# 4                                    NaN                             NaN
# 5                          mixed methods                             NaN
#
#   Dataset used (inductive) country of the institution of the first author  \
# 1                      NaN                                        Germany
# 2                   survey                                         Taiwan
# 3                      NaN                                        Germany
# 4                      NaN                                        Germany
# 5                      NaN                                          India
#
#    Is there an own subsection for policy recommendations? 1/0 Notes  \
# 1                                                0.0            NaN
# 2                                                0.0            NaN
# 3                                                0.0            NaN
# 4                                                0.0            NaN
# 5                                                1.0            NaN
#
#    Coding complete
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN

# %%
# if you want to reset the index
copy_df = copy_df.reset_index(drop=True) #if you use drop=False the index will be a new column in your dataframe
copy_df.head()
# Out:
#   Downloaded (1/0)                                            Authors  \
# 0                1                    Thiebes S.; Lins S.; Sunyaev A.
# 1                1                      Ho J.-H.; Lee G.-G.; Lu M.-T.
# 2                1                                        Bartmann M.
# 3                1                                        Halsband A.
# 4                1  Raman R.; Kumar Nair V.; Nedungadi P.; Ray I.;...
#
#                                    Author full names  \
# 0  Thiebes, Scott (56319399400); Lins, Sebastian ...
# 1  Ho, Juin-Hao (57218510909); Lee, Gwo-Guang (74...
# 2                     Bartmann, Marius (56512092600)
# 3                    Halsband, Aurélie (57562370000)
# 4  Raman, Raghu (36618183700); Kumar Nair, Vinith...
#
#                                         Author(s) ID  \
# 0              56319399400; 56318996100; 24779131200
# 1               57218510909; 7404852393; 55801461400
# 2                                        56512092600
# 3                                        57562370000
# 4  36618183700; 57647914700; 36069838600; 5883060...
#
#                                                Title  Year  \
# 0                Trustworthy artificial intelligence  2021
# 1  Exploring the implementation of a legal AI bot...  2020
# 2  The Ethics of AI-Powered Climate Nudging—How M...  2022
# 3       Sustainable AI and Intergenerational Justice  2022
# 4  Darkweb research: Past, present, and future tr...  2023
#
#                    Source title  Volume Issue Art. No. Page start Page end  \
# 0            Electronic Markets    31.0     2      NaN        447      464
# 1  Sustainability (Switzerland)    12.0    15     5991        NaN      NaN
# 2  Sustainability (Switzerland)    14.0     9     5153        NaN      NaN
# 3  Sustainability (Switzerland)    14.0     7     3922        NaN      NaN
# 4                       Heliyon     9.0    11   e22269        NaN      NaN
#
#    Page count  Cited by                            DOI  \
# 0        17.0       167     10.1007/s12525-020-00441-4
# 1         NaN         8             10.3390/su12155991
# 2         NaN         6             10.3390/su14095153
# 3         NaN         6             10.3390/su14073922
# 4         NaN         1  10.1016/j.heliyon.2023.e22269
#
#                                                 Link  \
# 0  https://www.scopus.com/inward/record.uri?eid=2...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
# 2  https://www.scopus.com/inward/record.uri?eid=2...
# 3  https://www.scopus.com/inward/record.uri?eid=2...
# 4  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                      Author Keywords  \
# 0  artificial intelligence; deep learning; emotio...
# 1  business; digital; education; entrepreneur; In...
# 2  Environmental effects; Green transition; Miner...
# 3  SDGs; ecological sustainability; intergenerati...
# 4  Artificial Intelligence; Climate Change; Energ...
#
#                                       Index Keywords  \
# 0                                                NaN
# 1                                                NaN
# 2  Asia; Economic and social effects; Economics; ...
# 3                                                NaN
# 4  India; artificial intelligence; climate change...
#
#                                             Abstract Document Type  \
# 0  Artificial intelligence (AI) brings forth many...       Article
# 1  This study explores the implementation of lega...       Article
# 2  The number of areas in which artificial intell...       Article
# 3  Recently, attention has been drawn to the sust...       Article
# 4  The Darkweb, part of the deep web, can be acce...       Article
#
#   Publication Stage Open Access  Source                 EID  SDG AI (yes/no)  \
# 0             Final         NaN  Scopus  2-s2.0-85148853990   16           1
# 1             Final         NaN  Scopus  2-s2.0-85168710066   16           1
# 2             Final         NaN  Scopus  2-s2.0-85174445734   16           1
# 3             Final         NaN  Scopus  2-s2.0-85139602753   16           1
# 4             Final         NaN  Scopus  2-s2.0-85185331385   16           1
#
#   Sustainability (yes/no) Type of AI \ninductive, text snippet  \
# 0                       1                              overall
# 1                       1                              overall
# 2                       1                              overall
# 3                       1                              overall
# 4                       1                                  nlp
#
#   Algorithm(s) used\ninductive, text snippet Method (1) vs. study object (2)  \
# 0                                unspecified                               2
# 1                                unspecified                               2
# 2                                unspecified                               2
# 3                                unspecified                               2
# 4                                unspecified                               2
#
#   AI as buzzword? (0/1) Core topic (only one)\nshort text snippet, inductive  \
# 0                     0                              Societal impact of AI
# 1                     0                                       legal AI bot
# 2                     0                 ethics of AI-based climate nudging
# 3                     0                          intergenerational justice
# 4                     0                                           dark web
#
#   Role of AI\ndeductive  Means (1) vs. end (2)  sustainability definition  \
# 0                    NaN                     2                        NaN
# 1                    NaN                     1                        NaN
# 2                    NaN                     1                        NaN
# 3                    NaN                     1  intergenerational justice
# 4                    NaN                     1                     SDG 16
#
#                  Sus_lvl empirical/conceptual/review  \
# 0    weak sustainability                  conceptual
# 1    weak sustainability                   empirical
# 2    weak sustainability                  conceptual
# 3  strong sustainability                  conceptual
# 4  strong sustainability                      review
#
#   spatial scale (individual, local, regional, national, supranational, global)  \
# 0                                                NaN
# 1                                           national
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   snapshot in time vs. longitudinal study  \
# 0                                     NaN
# 1                                 snaphot
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   temporal scale (past, present, future)  \
# 0                                    NaN
# 1                                present
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   qualitative/quantitative/mixed methods location of the study (country)  \
# 0                                    NaN                             NaN
# 1                           quantitative                          Taiwan
# 2                                    NaN                             NaN
# 3                                    NaN                             NaN
# 4                          mixed methods                             NaN
#
#   Dataset used (inductive) country of the institution of the first author  \
# 0                      NaN                                        Germany
# 1                   survey                                         Taiwan
# 2                      NaN                                        Germany
# 3                      NaN                                        Germany
# 4                      NaN                                          India
#
#    Is there an own subsection for policy recommendations? 1/0 Notes  \
# 0                                                0.0            NaN
# 1                                                0.0            NaN
# 2                                                0.0            NaN
# 3                                                0.0            NaN
# 4                                                1.0            NaN
#
#    Coding complete
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# ### Dropping row and columns and renaming them
# <div style="
#     border: 2px solid green;
#     border-radius: 8px;
#     padding: 0px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# </div>

# %%
#let's delete some columns, for example the first column
df = df.drop(columns="Downloaded (1/0)")

# %%
# if you want to delete some columns
df = df.drop(df.columns[6:12], axis=1)

# %%
#your want to drop several columns
columns_to_drop = ["Author Keywords", "Coding complete"]
df = df.drop(columns=columns_to_drop)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 865 entries, 10 to 891
# Data columns (total 38 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Authors                                                                       865 non-null    object
#  1   Author full names                                                             854 non-null    object
#  2   Author(s) ID                                                                  853 non-null    object
#  3   Title                                                                         864 non-null    object
#  4   Year                                                                          865 non-null    int64
#  5   Source title                                                                  865 non-null    object
#  6   Cited by                                                                      865 non-null    int64
#  7   DOI                                                                           859 non-null    object
#  8   Link                                                                          779 non-null    object
#  9   Index Keywords                                                                561 non-null    object
#  10  Abstract                                                                      834 non-null    object
#  11  Document Type                                                                 855 non-null    object
#  12  Publication Stage                                                             855 non-null    object
#  13  Open Access                                                                   551 non-null    object
#  14  Source                                                                        855 non-null    object
#  15  EID                                                                           865 non-null    object
#  16  SDG                                                                           865 non-null    int64
#  17  AI (yes/no)                                                                   864 non-null    object
#  18  Sustainability (yes/no)                                                       864 non-null    object
#  19  Type of AI
# inductive, text snippet                                           826 non-null    object
#  20  Algorithm(s) used
# inductive, text snippet                                     495 non-null    object
#  21  Method (1) vs. study object (2)                                               820 non-null    object
#  22  AI as buzzword? (0/1)                                                         786 non-null    object
#  23  Core topic (only one)
# short text snippet, inductive                           830 non-null    object
#  24  Role of AI
# deductive                                                          570 non-null    object
#  25  Means (1) vs. end (2)                                                         823 non-null    object
#  26  sustainability definition                                                     480 non-null    object
#  27  Sus_lvl                                                                       816 non-null    object
#  28  empirical/conceptual/review                                                   831 non-null    object
#  29  spatial scale (individual, local, regional, national, supranational, global)  555 non-null    object
#  30  snapshot in time vs. longitudinal study                                       618 non-null    object
#  31  temporal scale (past, present, future)                                        616 non-null    object
#  32  qualitative/quantitative/mixed methods                                        620 non-null    object
#  33  location of the study (country)                                               505 non-null    object
#  34  Dataset used (inductive)                                                      557 non-null    object
#  35  country of the institution of the first author                                830 non-null    object
#  36  Is there an own subsection for policy recommendations? 1/0                    825 non-null    float64
#  37  Notes                                                                         90 non-null     object
# dtypes: float64(1), int64(3), object(34)
# memory usage: 263.6+ KB

# %%
#dropping rows based on the index
df = df.drop(df.index[0:10], axis=0)

# %%
#checking duplicated rows based on a column, for example EID
df.duplicated(subset="EID").sum()
# Out:
# np.int64(44)

# %%
#which are those duplicated
df.loc[df.duplicated(subset="EID", keep=False),]
# Out:
# Empty DataFrame
# Columns: [Downloaded (1/0), Authors, Author full names, Author(s) ID, Title, Year, Source title, Volume, Issue, Art. No., Page start, Page end, Page count, Cited by, DOI, Link, Author Keywords, Index Keywords, Abstract, Document Type, Publication Stage, Open Access, Source, EID, SDG, AI (yes/no), Sustainability (yes/no), Type of AI
# inductive, text snippet, Algorithm(s) used
# inductive, text snippet, Method (1) vs. study object (2), AI as buzzword? (0/1), Core topic (only one)
# short text snippet, inductive, Role of AI
# deductive , Means (1) vs. end (2), sustainability definition, Sus_lvl, empirical/conceptual/review, spatial scale (individual, local, regional, national, supranational, global), snapshot in time vs. longitudinal study, temporal scale (past, present, future), qualitative/quantitative/mixed methods, location of the study (country), Dataset used (inductive), country of the institution of the first author, Is there an own subsection for policy recommendations? 1/0, Notes, Coding complete]
# Index: []

# %%
# dropping duplicates but from an specific column
df = df.drop_duplicates(subset="EID")

# %%
#checking missing values in the abstract column
df["Abstract"].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 888    False
# 889    False
# 890    False
# 891    False
# Name: Abstract, Length: 873, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 842 entries, 0 to 841
# Data columns (total 47 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Downloaded (1/0)                                                              720 non-null    object
#  1   Authors                                                                       842 non-null    object
#  2   Author full names                                                             831 non-null    object
#  3   Author(s) ID                                                                  830 non-null    object
#  4   Title                                                                         841 non-null    object
#  5   Year                                                                          842 non-null    int64
#  6   Source title                                                                  842 non-null    object
#  7   Volume                                                                        814 non-null    float64
#  8   Issue                                                                         497 non-null    object
#  9   Art. No.                                                                      499 non-null    object
#  10  Page start                                                                    347 non-null    object
#  11  Page end                                                                      347 non-null    object
#  12  Page count                                                                    346 non-null    float64
#  13  Cited by                                                                      842 non-null    int64
#  14  DOI                                                                           836 non-null    object
#  15  Link                                                                          756 non-null    object
#  16  Author Keywords                                                               589 non-null    object
#  17  Index Keywords                                                                537 non-null    object
#  18  Abstract                                                                      842 non-null    object
#  19  Document Type                                                                 833 non-null    object
#  20  Publication Stage                                                             833 non-null    object
#  21  Open Access                                                                   524 non-null    object
#  22  Source                                                                        833 non-null    object
#  23  EID                                                                           842 non-null    object
#  24  SDG                                                                           842 non-null    int64
#  25  AI (yes/no)                                                                   841 non-null    object
#  26  Sustainability (yes/no)                                                       841 non-null    object
#  27  Type of AI
# inductive, text snippet                                           804 non-null    object
#  28  Algorithm(s) used
# inductive, text snippet                                     476 non-null    object
#  29  Method (1) vs. study object (2)                                               797 non-null    object
#  30  AI as buzzword? (0/1)                                                         763 non-null    object
#  31  Core topic (only one)
# short text snippet, inductive                           807 non-null    object
#  32  Role of AI
# deductive                                                          556 non-null    object
#  33  Means (1) vs. end (2)                                                         798 non-null    object
#  34  sustainability definition                                                     452 non-null    object
#  35  Sus_lvl                                                                       794 non-null    object
#  36  empirical/conceptual/review                                                   808 non-null    object
#  37  spatial scale (individual, local, regional, national, supranational, global)  533 non-null    object
#  38  snapshot in time vs. longitudinal study                                       594 non-null    object
#  39  temporal scale (past, present, future)                                        592 non-null    object
#  40  qualitative/quantitative/mixed methods                                        598 non-null    object
#  41  location of the study (country)                                               485 non-null    object
#  42  Dataset used (inductive)                                                      534 non-null    object
#  43  country of the institution of the first author                                807 non-null    object
#  44  Is there an own subsection for policy recommendations? 1/0                    804 non-null    float64
#  45  Notes                                                                         89 non-null     object
#  46  Coding complete                                                               41 non-null     float64
# dtypes: float64(4), int64(3), object(40)
# memory usage: 309.3+ KB

# %%
# dropping all rows with a  missing values
df = df.dropna(axis=0, subset="Abstract")

# %%
#renaming columns
df = df.rename(columns={"Is there an own subsection for policy recommendations? 1/0": "policy_recommendations"}) #yes, dictionaries!!!

# %%
df.columns
# Out:
# Index(['Downloaded (1/0)', 'Authors', 'Author full names', 'Author(s) ID',
#        'Title', 'Year', 'Source title', 'Volume', 'Issue', 'Art. No.',
#        'Page start', 'Page end', 'Page count', 'Cited by', 'DOI', 'Link',
#        'Author Keywords', 'Index Keywords', 'Abstract', 'Document Type',
#        'Publication Stage', 'Open Access', 'Source', 'EID', 'SDG',
#        'AI (yes/no)', 'Sustainability (yes/no)',
#        'Type of AI \ninductive, text snippet',
#        'Algorithm(s) used\ninductive, text snippet',
#        'Method (1) vs. study object (2)', 'AI as buzzword? (0/1)',
#        'Core topic (only one)\nshort text snippet, inductive',
#        'Role of AI\ndeductive ', 'Means (1) vs. end (2)',
#        'sustainability definition', 'Sus_lvl', 'empirical/conceptual/review',
#        'spatial scale (individual, local, regional, national, supranational, global)',
#        'snapshot in time vs. longitudinal study',
#        'temporal scale (past, present, future)',
#        'qualitative/quantitative/mixed methods', 'study_location',
#        'dataset_used', 'country_instituton', 'policy_recommendations', 'Notes',
#        'Coding complete'],
#       dtype='object')

# %%
#you can also rename the column based on the position
columns_to_rename = {df.columns[-4]: "country_instituton"}
df = df.rename(columns=columns_to_rename)

# %%
#you can rename several columns at once
columns_to_rename = {df.columns[-6]: "study_location", df.columns[-5]: "dataset_used"}
df = df.rename(columns=columns_to_rename)

# %% [markdown]
# ## Index and Slicing
# <div style="
#     border: 4px solid blue;
#     border-radius: 8px;
#     padding: 0px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# </div>

# %%
#selecting a column
df["organization"]

# %%
#use double square brackets to be shown with df format
df[["organization"]]

# %%
#selecting rows by index position
df.iloc[2]

# %%
# or use double square brackets
df.iloc[[2]]

# %%
#selecting the first 20 rows with all columns
df.iloc[:20,:]

# %%
#selecting the first 10 rows with the first five columns
df.iloc[:10, :5]

# %%
#select the last 10 rows with the columns 3 to 8
df.iloc[-10:,3:9]

# %%
#selecting rows by label and index
df.loc[5:25, ["EID", "SDG"]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 842 entries, 0 to 841
# Data columns (total 47 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   Downloaded (1/0)                                                              720 non-null    object
#  1   Authors                                                                       842 non-null    object
#  2   Author full names                                                             831 non-null    object
#  3   Author(s) ID                                                                  830 non-null    object
#  4   Title                                                                         841 non-null    object
#  5   Year                                                                          842 non-null    int64
#  6   Source title                                                                  842 non-null    object
#  7   Volume                                                                        814 non-null    float64
#  8   Issue                                                                         497 non-null    object
#  9   Art. No.                                                                      499 non-null    object
#  10  Page start                                                                    347 non-null    object
#  11  Page end                                                                      347 non-null    object
#  12  Page count                                                                    346 non-null    float64
#  13  Cited by                                                                      842 non-null    int64
#  14  DOI                                                                           836 non-null    object
#  15  Link                                                                          756 non-null    object
#  16  Author Keywords                                                               589 non-null    object
#  17  Index Keywords                                                                537 non-null    object
#  18  Abstract                                                                      842 non-null    object
#  19  Document Type                                                                 833 non-null    object
#  20  Publication Stage                                                             833 non-null    object
#  21  Open Access                                                                   524 non-null    object
#  22  Source                                                                        833 non-null    object
#  23  EID                                                                           842 non-null    object
#  24  SDG                                                                           842 non-null    object
#  25  AI (yes/no)                                                                   841 non-null    object
#  26  Sustainability (yes/no)                                                       841 non-null    object
#  27  Type of AI
# inductive, text snippet                                           804 non-null    object
#  28  Algorithm(s) used
# inductive, text snippet                                     476 non-null    object
#  29  Method (1) vs. study object (2)                                               797 non-null    object
#  30  AI as buzzword? (0/1)                                                         763 non-null    object
#  31  Core topic (only one)
# short text snippet, inductive                           807 non-null    object
#  32  Role of AI
# deductive                                                          556 non-null    object
#  33  Means (1) vs. end (2)                                                         798 non-null    object
#  34  sustainability definition                                                     452 non-null    object
#  35  Sus_lvl                                                                       794 non-null    object
#  36  empirical/conceptual/review                                                   808 non-null    object
#  37  spatial scale (individual, local, regional, national, supranational, global)  533 non-null    object
#  38  snapshot in time vs. longitudinal study                                       594 non-null    object
#  39  temporal scale (past, present, future)                                        592 non-null    object
#  40  qualitative/quantitative/mixed methods                                        598 non-null    object
#  41  study_location                                                                485 non-null    object
#  42  dataset_used                                                                  534 non-null    object
#  43  country_instituton                                                            807 non-null    object
#  44  policy_recommendations                                                        804 non-null    float64
#  45  Notes                                                                         89 non-null     object
#  46  Coding complete                                                               41 non-null     float64
# dtypes: float64(4), int64(2), object(41)
# memory usage: 309.3+ KB

# %%
# conditional selection, for example all articles with more than 40 citations
df.loc[df["Cited by"]<40,]
# Out:
# 617

# %%
# transforming first SDG columnt to object
df["SDG"] = df["SDG"].astype(str)

# %%
# selecting only articles from SDG 10 and 5
df.loc[df["SDG"].isin(["5","10"]),]
# Out:
#     Downloaded (1/0)                                            Authors  \
# 327                1                                       Abalkheel A.
# 328                1  Aguilar-Esteva V.; Acosta-Banda A.; Carreño Ag...
# 329                1                     Alhazmi S.; Khan S.; Syed M.H.
# 330                1                                 Ally M.; Perris K.
# 331                1                                      Alshahrani A.
# ..               ...                                                ...
# 641                1  Salem K.S.; Clayson K.; Salas M.; Haque N.; Ra...
# 642                1                              Suha S.A.; Sanam T.F.
# 643                1  Manoj Kumar M.V.; Sastry N.K.B.; Moonesar I.A....
# 644                1      Yao K.-C.; Hsueh H.-W.; Huang M.-H.; Wu T.-C.
# 645                1                Reddy A.J.M.; Rani R.; Chaudhary V.
#
#                                      Author full names  \
# 327                  Abalkheel, Albatool (57296805400)
# 328  Aguilar-Esteva, Verónica (57222181545); Acosta...
# 329  Alhazmi, Samah (57209568391); Khan, Shahnawaz ...
# 330  Ally, Mohamed (7003506405); Perris, Kirk (6506...
# 331                      Alshahrani, Ali (57190291747)
# ..                                                 ...
# 641                                                NaN
# 642  Suha, Sayma Alam (57202155723); Sanam, Tahsina...
# 643  Manoj Kumar, M.V. (57218772075); Sastry, Nanda...
# 644  Yao, Kai-Chao (23399061700); Hsueh, Hsiu-Wen (...
# 645  Reddy, A. Jagan Mohan (57211857668); Rani, Rid...
#
#                                           Author(s) ID  \
# 327                                        57300000000
# 328  57222181545; 57222189876; 56258612100; 5625923...
# 329              57209568391; 57203386251; 36011645900
# 330                             7003506405; 6506383188
# 331                                        57200000000
# ..                                                 ...
# 641                                                NaN
# 642                           57202155723; 54974102000
# 643  57218772075; 37052785000; 57200596537; 5545360...
# 644  23399061700; 57206857155; 56301257600; 5720407...
# 645              57211857668; 55792671400; 57206164895
#
#                                                  Title  Year  \
# 327  AMALGAMATING BLOOM'S TAXONOMY AND ARTIFICIAL I...  2021
# 328  Sustainable Social Development through the Use...  2023
# 329  Learning-Related Sentiment Detection, Classifi...  2023
# 330  Artificial Intelligence in the Fourth Industri...  2022
# 331  The impact of ChatGPT on blended learning: Cur...  2023
# ..                                                 ...   ...
# 641  A critical review of existing and emerging tec...  2023
# 642  Exploring dominant factors for ensuring the su...  2023
# 643  Predicting Universal Healthcare Through Health...  2022
# 644  The Role of GARCH Effect on the Prediction of ...  2022
# 645  Technology for sustainable HRM: An empirical r...  2019
#
#                                           Source title  Volume Issue Art. No.  \
# 327  International Journal of English Language and ...    11.0     1      NaN
# 328                       Sustainability (Switzerland)    15.0     8     6498
# 329          Intelligent Automation and Soft Computing    36.0     3      NaN
# 330        Canadian Journal of Learning and Technology    48.0     4      NaN
# 331  International Journal of Data and Network Science     7.0     4      NaN
# ..                                                 ...     ...   ...      ...
# 641                                             Matter     NaN   NaN      NaN
# 642  International Journal of Information Managemen...     3.0     1   100170
# 643               Frontiers in Artificial Intelligence     5.0   NaN   887225
# 644                       Sustainability (Switzerland)    14.0     8     4459
# 645  International Journal of Innovative Technology...     9.0     1      NaN
#
#     Page start Page end  Page count  Cited by                           DOI  \
# 327         16       30        14.0        12      10.18488/5019.v11i1.4409
# 328        NaN      NaN         NaN         4            10.3390/su15086498
# 329       3487     3499        12.0         1     10.32604/iasc.2023.036297
# 330        NaN      NaN         NaN         0            10.21432/cjlt28287
# 331       2029     2040        11.0        12    10.5267/j.ijdns.2023.6.010
# ..         ...      ...         ...       ...                           ...
# 641        NaN      NaN         NaN         3    10.1016/j.matt.2023.08.003
# 642        NaN      NaN         NaN         4  10.1016/j.jjimei.2023.100170
# 643        NaN      NaN         NaN         4      10.3389/frai.2022.887225
# 644        NaN      NaN         NaN         4            10.3390/su14084459
# 645       2919     2924         5.0         4  10.35940/ijitee.A9108.119119
#
#                                                   Link  \
# 327                                                NaN
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
# ..                                                 ...
# 641                                                NaN
# 642  https://www.scopus.com/inward/record.uri?eid=2...
# 643  https://www.scopus.com/inward/record.uri?eid=2...
# 644  https://www.scopus.com/inward/record.uri?eid=2...
# 645  https://www.scopus.com/inward/record.uri?eid=2...
#
#                                        Author Keywords  \
# 327  Artificial intelligence; Bloom's taxonomy; COV...
# 328  artificial intelligence; big data; data scienc...
# 329  AI modeling; deep learning; optimization; sent...
# 330  4IR; Artificial intelligence; Fourth Industria...
# 331  Artificial Intelligence; Blended Learning; Cha...
# ..                                                 ...
# 641                                                NaN
# 642                                                NaN
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
#
#                                         Index Keywords  \
# 327                                                NaN
# 328  artificial intelligence; education; learning; ...
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
# ..                                                 ...
# 641                                                NaN
# 642                                                NaN
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
#
#                                               Abstract Document Type  \
# 327  During the coronavirus pandemic, remote learni...       Article
# 328  In this paper, we aimed to investigate how sus...        Review
# 329  Quality education is one of the primary object...       Article
# 330  There has been increasing interest in the use ...       Article
# 331  Designing sustainable and scalable educational...       Article
# ..                                                 ...           ...
# 641  Solid waste generation and its accumulation is...           NaN
# 642  Healthcare decision-making is a complicated as...       Article
# 643  The majority of the world's population is stil...       Article
# 644  Air pollution prediction is an important issue...       Article
# 645  In a highly competitive world of today charact...       Article
#
#     Publication Stage                                        Open Access  \
# 327             Final                All Open Access; Bronze Open Access
# 328             Final  All Open Access; Gold Open Access; Green Open ...
# 329             Final           All Open Access; Hybrid Gold Open Access
# 330             Final  All Open Access; Gold Open Access; Green Open ...
# 331             Final                  All Open Access; Gold Open Access
# ..                ...                                                ...
# 641               NaN                                                NaN
# 642             Final                  All Open Access; Gold Open Access
# 643             Final  All Open Access; Gold Open Access; Green Open ...
# 644             Final                  All Open Access; Gold Open Access
# 645             Final                All Open Access; Bronze Open Access
#
#      Source                 EID SDG AI (yes/no) Sustainability (yes/no)  \
# 327  Scopus  2-s2.0-85124629478   4         yes                     yes
# 328  Scopus  2-s2.0-85156127798   4         yes                     yes
# 329  Scopus  2-s2.0-85150761407   4         yes                     yes
# 330  Scopus  2-s2.0-85143217815   4         yes                     yes
# 331  Scopus  2-s2.0-85168959579   4         yes                     yes
# ..      ...                 ...  ..         ...                     ...
# 641     NaN  2-s2.0-85172726264   3           1                       1
# 642  Scopus  2-s2.0-85150763307   3           1                       1
# 643  Scopus  2-s2.0-85130230486   3           1                       1
# 644  Scopus  2-s2.0-85128475035   3           1                       1
# 645  Scopus  2-s2.0-85075126314   3           1                       1
#
#                   Type of AI \ninductive, text snippet  \
# 327                        natural language processing
# 328                            stays general, examples
# 329        semi-supervised learning; transfer learning
# 330                                  stays general, ML
# 331          natural language processing, ML (ChatGPT)
# ..                                                 ...
# 641  deep learning; AI; machine learning; neural ne...
# 642                                                 AI
# 643                                   Machine Learning
# 644                                   Machine Learning
# 645                                                 AI
#
#             Algorithm(s) used\ninductive, text snippet  \
# 327                                                NaN
# 328                                                NaN
# 329         XLNet neural network model; Adam optimizer
# 330                                                NaN
# 331                                                NaN
# ..                                                 ...
# 641                                                NaN
# 642                                                NaN
# 643                       ML Random Forest Tree method
# 644  GA-SVM (genetic algorithm support vector machi...
# 645                                                NaN
#
#     Method (1) vs. study object (2) AI as buzzword? (0/1)  \
# 327                               2                     0
# 328                               2                     0
# 329                               1                     0
# 330                               2                     0
# 331                               2                     0
# ..                              ...                   ...
# 641                               1                     0
# 642                               2                     0
# 643                               1                     0
# 644                               1                     0
# 645                               2                     1
#
#     Core topic (only one)\nshort text snippet, inductive  \
# 327  potential of AI and learning taxonomy on EFL f...
# 328                       Higher Education Innovations
# 329  Using AI to analyze learner sentiment for impr...
# 330  role of AI (4IR) in Education and Sustainable ...
# 331  potential of AI-powered tools to improve the s...
# ..                                                 ...
# 641                             solid waste management
# 642                         Healthcare decision making
# 643                          Universal Health Coverage
# 644                                      Air Pollution
# 645                         Human Resources Management
#
#                          Role of AI\ndeductive  Means (1) vs. end (2)  \
# 327                        system optimization?                     1
# 328                        system optimization?                     1
# 329              data mining and remote sensing                     1
# 330                        system optimization?                     1
# 331  increase effectiveness of blended learning                     1
# ..                                          ...                   ...
# 641                                         NaN                     1
# 642                                         NaN                     1
# 643                 Fast approximate simulation                     1
# 644                                 Forecasting                     1
# 645                                         NaN                     1
#
#                              sustainability definition                Sus_lvl  \
# 327  SDG 4, lifelong automated learning, accessibility                   weak
# 328  "Therefore, sustainable social development is ...                   weak
# 329                                                NaN                   weak
# 330  "Ultimately the intent is for all sectors of s...                 strong
# 331  "Sustainable development encompasses three dim...                 strong
# ..                                                 ...                    ...
# 641                                                NaN    weak sustainability
# 642                          three pillars; Brundtland                    NaN
# 643                                               SDGs  strong sustainability
# 644                                                NaN    weak sustainability
# 645                                                NaN    weak sustainability
#
#     empirical/conceptual/review  \
# 327                      review
# 328                      review
# 329                   empirical
# 330                      review
# 331                      review
# ..                          ...
# 641                 conceptual
# 642                   empirical
# 643                   empirical
# 644                   empirical
# 645                   Empirical
#
#     spatial scale (individual, local, regional, national, supranational, global)  \
# 327                                                NaN
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
# ..                                                 ...
# 641                                                NaN
# 642                                           national
# 643                                           national
# 644                                           Regional
# 645                                              Local
#
#     snapshot in time vs. longitudinal study  \
# 327                                     NaN
# 328                                     NaN
# 329                                snapshot
# 330                                     NaN
# 331                                     NaN
# ..                                      ...
# 641                                     NaN
# 642                                snapshot
# 643                            Longitudinal
# 644                            Longitudinal
# 645                            Longitudinal
#
#     temporal scale (past, present, future)  \
# 327                                    NaN
# 328                                    NaN
# 329                                present
# 330                                    NaN
# 331                                    NaN
# ..                                     ...
# 641                                    NaN
# 642                                present
# 643                                present
# 644                                present
# 645                                present
#
#     qualitative/quantitative/mixed methods  \
# 327                                    NaN
# 328                                    NaN
# 329                           quantitative
# 330                                    NaN
# 331                                    NaN
# ..                                     ...
# 641                                    NaN
# 642                           quantitative
# 643                           quantitative
# 644                           quantitative
# 645                           quantitative
#
#                                         study_location  \
# 327                                                NaN
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
# ..                                                 ...
# 641                                                NaN
# 642                                         Bangladesh
# 643  Brazil; Russia; India; China; South Africa; UK...
# 644                                             Taiwan
# 645                                                NaN
#
#                        dataset_used country_instituton  \
# 327                             NaN       Saudi Arabia
# 328                             NaN             Mexico
# 329  own dataset (1188 data points)       Saudi Arabia
# 330                             NaN             Canada
# 331                             NaN       Saudi Arabia
# ..                              ...                ...
# 641                             NaN                USA
# 642                          survey         Bangladesh
# 643       WHO data; World Bank data              India
# 644                    hard sensors             Taiwan
# 645                  non gov survey              India
#
#      policy_recommendations Notes  Coding complete
# 327                     0.0   NaN              NaN
# 328                     0.0   NaN              NaN
# 329                     0.0   NaN              NaN
# 330                     0.0   NaN              NaN
# 331                     1.0   NaN              NaN
# ..                      ...   ...              ...
# 641                     0.0   NaN              NaN
# 642                     0.0   NaN              NaN
# 643                     0.0   NaN              NaN
# 644                     0.0   NaN              NaN
# 645                     0.0   NaN              NaN
#
# [193 rows x 47 columns]

# %% [markdown]
# ## Plotting
# <div style="
#     border: 4px solid red;
#     border-radius: 8px;
#     padding: 0px;
#     margin: 10px 0;
#     background-color: inherit;
#     color: inherit;
# ">
# </div>

# %%
#!conda install -y packagename
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_counts

# %%
# Create bar plot
plt.bar("Platform", "count", data=df_counts)

# Add labels
plt.title("Basic Bar Plot")
plt.xlabel("Platform")
plt.ylabel("count")

# Show the plot
plt.show()
